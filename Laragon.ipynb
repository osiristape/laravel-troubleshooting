# %% [markdown]
# <a href="https://colab.research.google.com/github/osiristape/laravel-troubleshooting/blob/main/Laragon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **INTRODUCTION**

# %% [markdown]
# ```
# MVC Overview
# Laravel:
# - Migration system for database
# - MVC architecture support
# - Unit testing
# - Artisan
# - Library & modular
# - Security
#
#
# Model -> Database
# View -> User Interface
# Controller -> Logic
#
# Preparation of local environment
# - Laragon/Wamp or Xampp (Laragon - flexible access to other database)
# https://laragon.org/download/
# - Composer
# https://getcomposer.org/
# - Git Bash
# https://git-scm.com/downloads
# - VSCode
# https://code.visualstudio.com/
# - HeidiSQL or MySQL Workbench
#
# ```

# %% [markdown]
# ## **VSCode Extensions**
#
# ![image.png](data:image/png;base64,...) ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Reviews of using Laragon as substitute to xamp (2024)
# - xamp requires modification of port, security such as ssl protection, not a beginner friendly
# - laragon runs smooth without changing any php or httpf files (needs awareness of how everything works since it's GUI version of xamp/wamp)
#
# ```
# ## **Directory Structures**
#
# ![image.png](data:image/png;base64,...)
