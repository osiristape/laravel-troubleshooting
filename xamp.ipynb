# %% [markdown]
# <a href="https://colab.research.google.com/github/osiristape/laravel-troubleshooting/blob/main/xamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Xamp: MySQL shutdown unexpectedly.
#
# Possible solution #1
#
# ```
# [client]
# # password       = your_password
# port=3306 (change all port 3306 to 3307)
# socket="C:/xampp/mysql/mysql.sock"
# ```
#
# Possible solution #2
#
# ```
# visit C:\xampp
# view 'htdocs' folder properties
# click edit permission and allow all
# ```
# ![image.png](data:image/png;base64,...)
