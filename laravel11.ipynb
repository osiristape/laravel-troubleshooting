# %% [markdown]
# <a href="https://colab.research.google.com/github/osiristape/laravel-troubleshooting/blob/main/laravel11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Latest Version:
# Composer: 2.7.7 (Composer 2)
# PHP: 8.3
# Laravel: 11
#
# ----
# for demo only.
# ----
#
# Xamp (Choose WAMP instead)
# Apache
# 1. httpd.conf
# - ServerName localhost:XXXX
# - Listen XXXX
# 2. php.ini
# - open: entension=curl, extention=ssl, extension=zip
# - close: extension=php_openssl.dll
#
# common mistake:
# ; https://php.net/extension-dir
# extension_dir = "\ext" (remain as "\ext")
# ; On windows:
# extension_dir="C:\xampp\php\ext"
#
# "extension=ssl" issue in composer
# - composer config disable-tls true (unsafe)
# ----
# ***composer config -g --disabled-tls true
# ----
#
# - Laravel 11 requires Composer 2
#
# ----
# ***composer self-update --2
# ----
#
# ```

# %% [markdown]
# installation
# ```
# composer create-project laravel/laravel app-name
# ```

# %% [markdown]
# ![asset-1e8c25717c790c7fdfc709c50176aa75.png](data:image/png;base64,...)

# %% [markdown]
# ```
# cd app-name
#
# php artisan serve
# ```
#
# visit http://127.0.0.1:8000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
